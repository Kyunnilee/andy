# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
weights = [72.8, 74.3, 75, 75.2, 74.9, 75.2, 75.9, 76, 75.1, 75.2, 75, 75.3, 74.7]
muscle = [34.8, 35.5, 36.8, 36.9, 35.2, 36.2, 36.3, 36.5, 36.1, 35.4, 35.7, 36.6, 36.0]
fat = [15.6, 15.4, 13.4, 13.7, 17, 15.3, 15.7, 15.3, 15.4, 16.7, 16.1, 14.5, 15]

assert len(weights) == len(muscle) and len(muscle) == len(fat)

# %%
x = weights
y = muscle

sns.regplot(x, y, ci=None)
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
plt.plot(weights)

# %%
plt.plot(muscle)

# %%
plt.plot(fat)
